# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Pandas for Exploratory Data Analysis I
# by [@josephofiowa](https://twitter.com/josephofiowa)
#
# Pandas is the most prominent Python library for exploratory data analysis (EDA). The functions Pandas supports are integral to understanding, formatting, and preparing our data. Formally, we use Pandas to investigate, wrangle, munge, and clean our data. Pandas is the Swiss Army Knife of data manipulation!
#
#
# We'll have two coding-heavy sessions on Pandas. In this one, we'll use Pandas to:
#  - Read in a dataset
#  - Investigate a dataset's integrity
#  - Filter, sort, and manipulate a DataFrame's series

# %% [markdown]
# ## About the Dataset: Adventureworks Cycles
#
# <img align="right" src="http://lh6.ggpht.com/_XjcDyZkJqHg/TPaaRcaysbI/AAAAAAAAAFo/b1U3q-qbTjY/AdventureWorks%20Logo%5B5%5D.png?imgmax=800">
#
# For today's Pandas exercises, we will be using a dataset developed by Microsoft for training purposes in SQL server, known the [Adventureworks Cycles 2014OLTP Database](https://github.com/Microsoft/sql-server-samples/releases/tag/adventureworks). It is based on a fictitious company called Adventure Works Cycles (AWC), a multinational manufacturer and seller of bicycles and accessories. The company is based in Bothell, Washington, USA and has regional sales offices in several countries. We will be looking at a single table from this database, the Production.Product table, which outlines some of the products this company sells.
#
# A full data dictionary can be viewed [here](https://www.sqldatadictionary.com/AdventureWorks2014/).

# %% [markdown]
# Let's take a closer look at the Production.Product table [data dictionary](https://www.sqldatadictionary.com/AdventureWorks2014/Production.Product.html), which is a description of the fields (columns) in the table (the .csv file we will import below):
# - **ProductID** - Primary key for Product records.
# - **Name** - Name of the product.
# - **ProductNumber** - Unique product identification number.
# - **MakeFlag** - 0 = Product is purchased, 1 = Product is manufactured in-house.
# - **FinishedGoodsFlag** - 0 = Product is not a salable item. 1 = Product is salable.
# - **Color** - Product color.
# - **SafetyStockLevel** - Minimum inventory quantity.
# - **ReorderPoint** - Inventory level that triggers a purchase order or work order.
# - **StandardCost** - Standard cost of the product.
# - **ListPrice** - Selling price.
# - **Size** - Product size.
# - **SizeUnitMeasureCode** - Unit of measure for the Size column.
# - **WeightUnitMeasureCode** - Unit of measure for the Weight column.
# - **DaysToManufacture** - Number of days required to manufacture the product.
# - **ProductLine** - R = Road, M = Mountain, T = Touring, S = Standard
# - **Class** - H = High, M = Medium, L = Low
# - **Style** - W = Womens, M = Mens, U = Universal
# - **ProductSubcategoryID** - Product is a member of this product subcategory. Foreign key to ProductSubCategory.ProductSubCategoryID.
# - **ProductModelID** - Product is a member of this product model. Foreign key to ProductModel.ProductModelID.
# - **SellStartDate** - Date the product was available for sale.
# - **SellEndDate** - Date the product was no longer available for sale.
# - **DiscontinuedDate** - Date the product was discontinued.
# - **rowguid** - ROWGUIDCOL number uniquely identifying the record. Used to support a merge replication sample.
# - **ModifiedDate** - Date and time the record was last updated.

# %% [markdown]
# ## Importing Pandas
#
# To [import a library](https://docs.python.org/3/reference/import.html), we write `import` and the library name. For Pandas, is it common to name the library `pd` so that when we reference a function from the Pandas library, we only write `pd` to reference the aliased [namespace](https://docs.python.org/3/tutorial/classes.html#python-scopes-and-namespaces) -- not `pandas`.

# %%
import pandas as pd

# %%
# we can see the details about the imported package by referencing its private class propertys:
print(f'I am using {pd.__name__} \
Version: {pd.__version__}.\n\
It is installed at: {pd.__path__}')
# Out:
# I am using pandas Version: 0.24.2.
# It is installed at: ['//anaconda3/lib/python3.7/site-packages/pandas']

# %% [markdown]
# ## Reading in Data
#
# Pandas dramatically simplifies the process of reading in data. When we say "reading in data," we mean loading a file into our machine's memory.
#
# When you have a CSV, for example, and then you double-click to open it in Microsoft Excel, the open file is "read into memory." You can now manipulate the CSV.
#
# When we read data into memory in Python, we are creating an object. We will soon explore this object. _(And, as an aside, when we have a file that is greater than the size of our computer's memory, this is approaching "Big Data.")_

# %% [markdown]
# Because we are working with a CSV, we will use the [read CSV](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) method.<br>A [delimiter](https://en.wikipedia.org/wiki/Delimiter-separated_values) is a character that separates fields (columns) in the imported file. Just because a file says `.csv` does not necessarily mean that a comma is used as the delimiter. In this case, we have a tab character as the delimiter for our columns, so we will be using `sep='\t'` to tell pandas to 'cut' the columns every time it sees a [tab character in the file](http://vim.wikia.com/wiki/Showing_the_ASCII_value_of_the_current_character).

# %%
# read the dataset as a DataFrame into a variable named 'prod'
prod = pd.read_csv("../data/Production.Product.csv", sep = "\t")

# %%
# show the head of this dataset
prod.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0        0.0  ...         NaN   NaN   NaN                   NaN
# 1        0.0  ...         NaN   NaN   NaN                   NaN
# 2        0.0  ...         NaN   NaN   NaN                   NaN
# 3        0.0  ...         NaN   NaN   NaN                   NaN
# 4        0.0  ...         NaN   NaN   NaN                   NaN
#
#    ProductModelID        SellStartDate SellEndDate DiscontinuedDate  \
# 0             NaN  2008-04-30 00:00:00         NaN              NaN
# 1             NaN  2008-04-30 00:00:00         NaN              NaN
# 2             NaN  2008-04-30 00:00:00         NaN              NaN
# 3             NaN  2008-04-30 00:00:00         NaN              NaN
# 4             NaN  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000
# 2  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}  2014-02-08 10:01:36.827000000
# 3  {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}  2014-02-08 10:01:36.827000000
# 4  {E73E9750-603B-4131-89F5-3DD15ED5FF80}  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %% [markdown]
# *Documentation Pause*
#
# How did we know how to use `pd.read_csv`? Let's take a look at the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html). Note the first argument required (`filepath`).
# > Take a moment to dissect other arguments and options when reading in data.

# %% [markdown]
# We have just created a data structure called a `DataFrame`. See?

# %%
# show the type of this 'prod' dataset
type(prod)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Inspecting our DataFrame: The basics
#
# We'll now perform basic operations on the DataFrame, denoted with comments.

# %%
# print the first and last 3 rows
prod.tail()
# Out:
#      ProductID                Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 499        995   ML Bottom Bracket       BB-8107         1                  1
# 500        996   HL Bottom Bracket       BB-9108         1                  1
# 501        997  Road-750 Black, 44    BK-R19B-44         1                  1
# 502        998  Road-750 Black, 48    BK-R19B-48         1                  1
# 503        999  Road-750 Black, 52    BK-R19B-52         1                  1
#
#      Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 499    NaN               500           375       44.9506     101.24  ...
# 500    NaN               500           375       53.9416     121.49  ...
# 501  Black               100            75      343.6496     539.99  ...
# 502  Black               100            75      343.6496     539.99  ...
# 503  Black               100            75      343.6496     539.99  ...
#
#     ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 499         NaN    M    NaN                   5.0            96.0
# 500         NaN    H    NaN                   5.0            97.0
# 501          R     L     U                    2.0            31.0
# 502          R     L     U                    2.0            31.0
# 503          R     L     U                    2.0            31.0
#
#            SellStartDate SellEndDate DiscontinuedDate  \
# 499  2013-05-30 00:00:00         NaN              NaN
# 500  2013-05-30 00:00:00         NaN              NaN
# 501  2013-05-30 00:00:00         NaN              NaN
# 502  2013-05-30 00:00:00         NaN              NaN
# 503  2013-05-30 00:00:00         NaN              NaN
#
#                                     rowguid                   ModifiedDate
# 499  {71AB847F-D091-42D6-B735-7B0C2D82FC84}  2014-02-08 10:01:36.827000000
# 500  {230C47C5-08B2-4CE3-B706-69C0BDD62965}  2014-02-08 10:01:36.827000000
# 501  {44CE4802-409F-43AB-9B27-CA53421805BE}  2014-02-08 10:01:36.827000000
# 502  {3DE9A212-1D49-40B6-B10A-F564D981DBDE}  2014-02-08 10:01:36.827000000
# 503  {AE638923-2B67-4679-B90E-ABBAB17DCA31}  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %% [markdown]
# Notice that `.head()` is a method (denoted by parantheses), so it takes arguments.

# %% [markdown]
# **Class Question:**
# - What do you think changes if we pass a different number `head()` argument?
# - How would we print the last 5 rows?

# %%
# identify the shape (rows by columns)
prod.shape
# Out:
# (504, 25)

# %% [markdown]
# Here we have 504 rows, and 25 columns. This is a tuple, so we can extract the parts using indexing:

# %%
# print the number of rows
prod.shape[0]
# Out:
# 504

# %% [markdown]
# ## Using the index
# An [index](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.html) is an immutable ndarray implementing an ordered, sliceable set. The basic object storing axis labels for all pandas objects. Think of it as a 'row address' for your data frame (table). It is best practice to explicitly set the index of your dataframe, as these are commonly used as [primary keys](https://en.wikipedia.org/wiki/Primary_key) which can be used to [join](https://www.w3schools.com/sql/sql_join.asp) your dataframe to other dataframes.
#
# The dataframe can store different types (int, string, datetime), and when importing data will automatically assign a number to each row, starting at zero and counting up. You can overwrite this, which is what we are going to do.

# %%
# display the index as it sits (auto-generated upon import)
prod.index
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
# note that our auto-generated index has no name

# %%
# Here we are looking at three columns;
# the one on the left is the index (automatically generated upon import by pandas)
# 'ProductID' is our PK (primary key) from our imported table. 'Name' is a data column.
# Notice that the generated index starts at zero and our PK starts at 1.

# %%
# Setting the index overwrites the automatically generated index
# with our PK, which resided in the 'ProductID' column.
prod.set_index("ProductID", inplace = True)

# %%
# Note how our index property has changed as a result
prod.head()
# Out:
#                             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race       AR-5381         0                  0
# 2                   Bearing Ball       BA-8327         0                  0
# 3                BB Ball Bearing       BE-2349         1                  0
# 4          Headset Ball Bearings       BE-2908         0                  0
# 316                        Blade       BL-2036         1                  0
#
#           Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# ProductID
# 1           NaN              1000           750           0.0        0.0  NaN
# 2           NaN              1000           750           0.0        0.0  NaN
# 3           NaN               800           600           0.0        0.0  NaN
# 4           NaN               800           600           0.0        0.0  NaN
# 316         NaN               800           600           0.0        0.0  NaN
#
#            ... ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID  ...
# 1          ...         NaN   NaN    NaN                   NaN            NaN
# 2          ...         NaN   NaN    NaN                   NaN            NaN
# 3          ...         NaN   NaN    NaN                   NaN            NaN
# 4          ...         NaN   NaN    NaN                   NaN            NaN
# 316        ...         NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %%
# And our index has also inherited the name of our 'ProductID' column
prod.index
# Out:
# Int64Index([  1,   2,   3,   4, 316, 317, 318, 319, 320, 321,
#             ...
#             990, 991, 992, 993, 994, 995, 996, 997, 998, 999],
#            dtype='int64', name='ProductID', length=504)

# %% [markdown]
# ## Column headers and datatypes

# %%
# print the columns
prod.columns
# Out:
# Index(['Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag', 'Color',
#        'SafetyStockLevel', 'ReorderPoint', 'StandardCost', 'ListPrice', 'Size',
#        'SizeUnitMeasureCode', 'WeightUnitMeasureCode', 'Weight',
#        'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
# examine the datatypes of the columns
# note that these were automatically inferred by pandas upon import!
prod.dtypes
# Out:
# Name                      object
# ProductNumber             object
# MakeFlag                   int64
# FinishedGoodsFlag          int64
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# StandardCost             float64
# ListPrice                float64
# Size                      object
# SizeUnitMeasureCode       object
# WeightUnitMeasureCode     object
# Weight                   float64
# DaysToManufacture          int64
# ProductLine               object
# Class                     object
# Style                     object
# ProductSubcategoryID     float64
# ProductModelID           float64
# SellStartDate             object
# SellEndDate               object
# DiscontinuedDate         float64
# rowguid                   object
# ModifiedDate              object
# dtype: object

# %% [markdown]
# **Class Question:** Why do datatypes matter? What operations could we perform on some datatypes that we could not on others? Note the importance of this in checking dataset integrity.

# %% [markdown]
# ## Selecting a Column
#
# We can select columns in two ways. Either we treat the column as an attribute of the DataFrame or we index the DataFrame for a specific element (in this case, the element is a column name).

# %%
# show the difference in data types by using single and double square brackets
prod["Name"]
# type(prod["Name"])  # series
# Out:
# ProductID
# 1                Adjustable Race
# 2                   Bearing Ball
# 3                BB Ball Bearing
# 4          Headset Ball Bearings
# 316                        Blade
# 317                  LL Crankarm
# 318                  ML Crankarm
# 319                  HL Crankarm
# 320              Chainring Bolts
# 321                Chainring Nut
# 322                    Chainring
# 323                   Crown Race
# 324                  Chain Stays
# 325                      Decal 1
# 326                      Decal 2
# 327                    Down Tube
# 328            Mountain End Caps
# 329                Road End Caps
# 330             Touring End Caps
# 331                     Fork End
# 332                    Freewheel
# 341                Flat Washer 1
# 342                Flat Washer 6
# 343                Flat Washer 2
# 344                Flat Washer 9
# 345                Flat Washer 4
# 346                Flat Washer 3
# 347                Flat Washer 8
# 348                Flat Washer 5
# 349                Flat Washer 7
#                  ...
# 970        Touring-2000 Blue, 46
# 971        Touring-2000 Blue, 50
# 972        Touring-2000 Blue, 54
# 973        Road-350-W Yellow, 40
# 974        Road-350-W Yellow, 42
# 975        Road-350-W Yellow, 44
# 976        Road-350-W Yellow, 48
# 977           Road-750 Black, 58
# 978        Touring-3000 Blue, 44
# 979        Touring-3000 Blue, 50
# 980    Mountain-400-W Silver, 38
# 981    Mountain-400-W Silver, 40
# 982    Mountain-400-W Silver, 42
# 983    Mountain-400-W Silver, 46
# 984      Mountain-500 Silver, 40
# 985      Mountain-500 Silver, 42
# 986      Mountain-500 Silver, 44
# 987      Mountain-500 Silver, 48
# 988      Mountain-500 Silver, 52
# 989       Mountain-500 Black, 40
# 990       Mountain-500 Black, 42
# 991       Mountain-500 Black, 44
# 992       Mountain-500 Black, 48
# 993       Mountain-500 Black, 52
# 994            LL Bottom Bracket
# 995            ML Bottom Bracket
# 996            HL Bottom Bracket
# 997           Road-750 Black, 44
# 998           Road-750 Black, 48
# 999           Road-750 Black, 52
# Name: Name, Length: 504, dtype: object

# %%
prod[["Name"]]
# type(prod[["Name"]]) # dataframe
# Out:
#                                 Name
# ProductID
# 1                    Adjustable Race
# 2                       Bearing Ball
# 3                    BB Ball Bearing
# 4              Headset Ball Bearings
# 316                            Blade
# 317                      LL Crankarm
# 318                      ML Crankarm
# 319                      HL Crankarm
# 320                  Chainring Bolts
# 321                    Chainring Nut
# 322                        Chainring
# 323                       Crown Race
# 324                      Chain Stays
# 325                          Decal 1
# 326                          Decal 2
# 327                        Down Tube
# 328                Mountain End Caps
# 329                    Road End Caps
# 330                 Touring End Caps
# 331                         Fork End
# 332                        Freewheel
# 341                    Flat Washer 1
# 342                    Flat Washer 6
# 343                    Flat Washer 2
# 344                    Flat Washer 9
# 345                    Flat Washer 4
# 346                    Flat Washer 3
# 347                    Flat Washer 8
# 348                    Flat Washer 5
# 349                    Flat Washer 7
# ...                              ...
# 970            Touring-2000 Blue, 46
# 971            Touring-2000 Blue, 50
# 972            Touring-2000 Blue, 54
# 973            Road-350-W Yellow, 40
# 974            Road-350-W Yellow, 42
# 975            Road-350-W Yellow, 44
# 976            Road-350-W Yellow, 48
# 977               Road-750 Black, 58
# 978            Touring-3000 Blue, 44
# 979            Touring-3000 Blue, 50
# 980        Mountain-400-W Silver, 38
# 981        Mountain-400-W Silver, 40
# 982        Mountain-400-W Silver, 42
# 983        Mountain-400-W Silver, 46
# 984          Mountain-500 Silver, 40
# 985          Mountain-500 Silver, 42
# 986          Mountain-500 Silver, 44
# 987          Mountain-500 Silver, 48
# 988          Mountain-500 Silver, 52
# 989           Mountain-500 Black, 40
# 990           Mountain-500 Black, 42
# 991           Mountain-500 Black, 44
# 992           Mountain-500 Black, 48
# 993           Mountain-500 Black, 52
# 994                LL Bottom Bracket
# 995                ML Bottom Bracket
# 996                HL Bottom Bracket
# 997               Road-750 Black, 44
# 998               Road-750 Black, 48
# 999               Road-750 Black, 52
#
# [504 rows x 1 columns]

# %%
# select the Name column only, returned as a Series object

# %%
# select the Name column only, returned as a DataFrame object

# %%
# selecting > 1 column (must use double brackets!)
# prod[["Name", "Color", "MakeFlag"]]
cols_to_subset = ["Name", "Color", "MakeFlag"]
prod[cols_to_subset]
# Out:
#                                 Name   Color  MakeFlag
# ProductID
# 1                    Adjustable Race     NaN         0
# 2                       Bearing Ball     NaN         0
# 3                    BB Ball Bearing     NaN         1
# 4              Headset Ball Bearings     NaN         0
# 316                            Blade     NaN         1
# 317                      LL Crankarm   Black         0
# 318                      ML Crankarm   Black         0
# 319                      HL Crankarm   Black         0
# 320                  Chainring Bolts  Silver         0
# 321                    Chainring Nut  Silver         0
# 322                        Chainring   Black         0
# 323                       Crown Race     NaN         0
# 324                      Chain Stays     NaN         1
# 325                          Decal 1     NaN         0
# 326                          Decal 2     NaN         0
# 327                        Down Tube     NaN         1
# 328                Mountain End Caps     NaN         1
# 329                    Road End Caps     NaN         1
# 330                 Touring End Caps     NaN         1
# 331                         Fork End     NaN         1
# 332                        Freewheel  Silver         0
# 341                    Flat Washer 1     NaN         0
# 342                    Flat Washer 6     NaN         0
# 343                    Flat Washer 2     NaN         0
# 344                    Flat Washer 9     NaN         0
# 345                    Flat Washer 4     NaN         0
# 346                    Flat Washer 3     NaN         0
# 347                    Flat Washer 8     NaN         0
# 348                    Flat Washer 5     NaN         0
# 349                    Flat Washer 7     NaN         0
# ...                              ...     ...       ...
# 970            Touring-2000 Blue, 46    Blue         1
# 971            Touring-2000 Blue, 50    Blue         1
# 972            Touring-2000 Blue, 54    Blue         1
# 973            Road-350-W Yellow, 40  Yellow         1
# 974            Road-350-W Yellow, 42  Yellow         1
# 975            Road-350-W Yellow, 44  Yellow         1
# 976            Road-350-W Yellow, 48  Yellow         1
# 977               Road-750 Black, 58   Black         1
# 978            Touring-3000 Blue, 44    Blue         1
# 979            Touring-3000 Blue, 50    Blue         1
# 980        Mountain-400-W Silver, 38  Silver         1
# 981        Mountain-400-W Silver, 40  Silver         1
# 982        Mountain-400-W Silver, 42  Silver         1
# 983        Mountain-400-W Silver, 46  Silver         1
# 984          Mountain-500 Silver, 40  Silver         1
# 985          Mountain-500 Silver, 42  Silver         1
# 986          Mountain-500 Silver, 44  Silver         1
# 987          Mountain-500 Silver, 48  Silver         1
# 988          Mountain-500 Silver, 52  Silver         1
# 989           Mountain-500 Black, 40   Black         1
# 990           Mountain-500 Black, 42   Black         1
# 991           Mountain-500 Black, 44   Black         1
# 992           Mountain-500 Black, 48   Black         1
# 993           Mountain-500 Black, 52   Black         1
# 994                LL Bottom Bracket     NaN         1
# 995                ML Bottom Bracket     NaN         1
# 996                HL Bottom Bracket     NaN         1
# 997               Road-750 Black, 44   Black         1
# 998               Road-750 Black, 48   Black         1
# 999               Road-750 Black, 52   Black         1
#
# [504 rows x 3 columns]

# %% [markdown]
# **Class Question:** What if we wanted to select a column that has a space in it? Which method from the above two would we use? Why?

# %%
prod.head()
# Out:
#                             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race       AR-5381         0                  0
# 2                   Bearing Ball       BA-8327         0                  0
# 3                BB Ball Bearing       BE-2349         1                  0
# 4          Headset Ball Bearings       BE-2908         0                  0
# 316                        Blade       BL-2036         1                  0
#
#           Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# ProductID
# 1           NaN              1000           750           0.0        0.0  NaN
# 2           NaN              1000           750           0.0        0.0  NaN
# 3           NaN               800           600           0.0        0.0  NaN
# 4           NaN               800           600           0.0        0.0  NaN
# 316         NaN               800           600           0.0        0.0  NaN
#
#            ... ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID  ...
# 1          ...         NaN   NaN    NaN                   NaN            NaN
# 2          ...         NaN   NaN    NaN                   NaN            NaN
# 3          ...         NaN   NaN    NaN                   NaN            NaN
# 4          ...         NaN   NaN    NaN                   NaN            NaN
# 316        ...         NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %%
# rename one or more columns with a dictionary. Note: inplace=False will return a new dataframe,
# but leave the original dataframe untouched. Change this to True to modify the original dataframe.
prod.rename(columns={"Name": "ProductName", "ProductNumber": "Number"}, inplace=True)

# %%
prod.head()
# Out:
#                      ProductName   Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0   NaN
# 2                   Bearing Ball  BA-8327         0                  0   NaN
# 3                BB Ball Bearing  BE-2349         1                  0   NaN
# 4          Headset Ball Bearings  BE-2908         0                  0   NaN
# 316                        Blade  BL-2036         1                  0   NaN
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 1                      1000           750           0.0        0.0  NaN  ...
# 2                      1000           750           0.0        0.0  NaN  ...
# 3                       800           600           0.0        0.0  NaN  ...
# 4                       800           600           0.0        0.0  NaN  ...
# 316                     800           600           0.0        0.0  NaN  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 1                 NaN   NaN    NaN                   NaN            NaN
# 2                 NaN   NaN    NaN                   NaN            NaN
# 3                 NaN   NaN    NaN                   NaN            NaN
# 4                 NaN   NaN    NaN                   NaN            NaN
# 316               NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %% [markdown]
# Renaming **ALL** columns with a new list of column names.
#
# Note that the `pd.DataFrame.columns` property can be cast to a `list` type. Originally, it's a `pd.core.indexes.base.Index` object:

# %%
# print('My columns look like:\n', prod.columns)
# print('\nAnd the type is:\n', type(prod.columns))

# %% [markdown]
# We can explicitly cast these to a list object as such, by using the built-in `list()` function:

# %%
# print('Now my columns look like:\n', list(prod.columns))
# print('\nAnd are of type:\n', type(list(prod.columns)))

# %% [markdown]
# We can place these columns into a variable, `cols`:

# %%
# declare a list of strings - these strings will become the new column names
cols = list(prod.columns)

# %%
cols[0] = "Name"
cols
# Out:
# ['Name',
#  'Number',
#  'MakeFlag',
#  'FinishedGoodsFlag',
#  'Color',
#  'SafetyStockLevel',
#  'ReorderPoint',
#  'StandardCost',
#  'ListPrice',
#  'Size',
#  'SizeUnitMeasureCode',
#  'WeightUnitMeasureCode',
#  'Weight',
#  'DaysToManufacture',
#  'ProductLine',
#  'Class',
#  'Style',
#  'ProductSubcategoryID',
#  'ProductModelID',
#  'SellStartDate',
#  'SellEndDate',
#  'DiscontinuedDate',
#  'rowguid',
#  'ModifiedDate']

# %%
prod.columns = cols

# %%
prod.head()
# Out:
#                             Name   Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0   NaN
# 2                   Bearing Ball  BA-8327         0                  0   NaN
# 3                BB Ball Bearing  BE-2349         1                  0   NaN
# 4          Headset Ball Bearings  BE-2908         0                  0   NaN
# 316                        Blade  BL-2036         1                  0   NaN
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 1                      1000           750           0.0        0.0  NaN  ...
# 2                      1000           750           0.0        0.0  NaN  ...
# 3                       800           600           0.0        0.0  NaN  ...
# 4                       800           600           0.0        0.0  NaN  ...
# 316                     800           600           0.0        0.0  NaN  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 1                 NaN   NaN    NaN                   NaN            NaN
# 2                 NaN   NaN    NaN                   NaN            NaN
# 3                 NaN   NaN    NaN                   NaN            NaN
# 4                 NaN   NaN    NaN                   NaN            NaN
# 316               NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %% [markdown]
# We can use list indexing to mutate the columns we want:

# %%
# overwrite one of the column names using list indexing

# %% [markdown]
# Finally, we can set the `pd.DataFrame.columns` property (this is a settable class property), to the new `cols` list, overwriting the existing columns header names:

# %%
# Note that our first column name has changed from 'Name' to 'NewName'

# %%
# display the final result of the 'NewName' column
# prod.head(3)[['NewName']]

# %% [markdown]
# ## Common Column Operations
#
# While this is non-comprehensive, these are a few key column-specific data checks.

# %% [markdown]
# **Descriptive statistics:**  the minimum, first quartile, median, third quartile, and maximum.
#
# (And more! The mean too.)

# %% [markdown]
# Five Number Summary (all assumes numeric data):
# - **Min:** The smallest value in the column
# - **Max:** The largest value in the column
# - **Quartile:** A quartile is one fourth of our data
#     - **First quartile:** This is the bottom most 25 percent
#     - **Median:** The middle value. (Line all values biggest to smallest - median is the middle!) Also the 50th percentile
#     - **Third quartile:** This the the top 75 percentile of our data

# %% [markdown]
# ![](https://www.mathsisfun.com/data/images/quartiles-a.svg)

# %%
# note - .describe() *default* only checks numeric datatypes
# show .describe() for the 'MakeFlag', 'SafetyStockLevel', 'StandardCost' fields.
prod[["MakeFlag", "SafetyStockLevel", "StandardCost"]].describe()
# Out:
#          MakeFlag  SafetyStockLevel  StandardCost
# count  504.000000        504.000000    504.000000
# mean     0.474206        535.150794    258.602961
# std      0.499830        374.112954    461.632808
# min      0.000000          4.000000      0.000000
# 25%      0.000000        100.000000      0.000000
# 50%      0.000000        500.000000     23.372200
# 75%      1.000000       1000.000000    317.075825
# max      1.000000       1000.000000   2171.294200

# %% [markdown]
# **Value Counts:** `pd.Series.value_counts()` count the occurrence of each value within our series.

# %%
# show the most popular product colors (aggregated by count, descending by default)
prod.head()
# Out:
#                            Name1  Number1  MakeFlag1  FinishedGoodsFlag1  \
# ProductID
# 1                Adjustable Race  AR-5381          0                   0
# 2                   Bearing Ball  BA-8327          0                   0
# 3                BB Ball Bearing  BE-2349          1                   0
# 4          Headset Ball Bearings  BE-2908          0                   0
# 316                        Blade  BL-2036          1                   0
#
#           Color1  SafetyStockLevel1  ReorderPoint1  StandardCost1  ListPrice1  \
# ProductID
# 1            NaN               1000            750            0.0         0.0
# 2            NaN               1000            750            0.0         0.0
# 3            NaN                800            600            0.0         0.0
# 4            NaN                800            600            0.0         0.0
# 316          NaN                800            600            0.0         0.0
#
#           Size1  ... ProductLine1 Class1  Style1  ProductSubcategoryID1  \
# ProductID        ...
# 1           NaN  ...          NaN    NaN     NaN                    NaN
# 2           NaN  ...          NaN    NaN     NaN                    NaN
# 3           NaN  ...          NaN    NaN     NaN                    NaN
# 4           NaN  ...          NaN    NaN     NaN                    NaN
# 316         NaN  ...          NaN    NaN     NaN                    NaN
#
#           ProductModelID1       SellStartDate1 SellEndDate1  \
# ProductID
# 1                     NaN  2008-04-30 00:00:00          NaN
# 2                     NaN  2008-04-30 00:00:00          NaN
# 3                     NaN  2008-04-30 00:00:00          NaN
# 4                     NaN  2008-04-30 00:00:00          NaN
# 316                   NaN  2008-04-30 00:00:00          NaN
#
#            DiscontinuedDate1                                rowguid1  \
# ProductID
# 1                        NaN  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2                        NaN  {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3                        NaN  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4                        NaN  {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316                      NaN  {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                            ModifiedDate1
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %%
prod["Color"].value_counts().sum()
# Out:
# 256

# %%
prod["Color"].unique()
# Out:
# array([nan, 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %% [markdown]
# **Unique values:** Determine the number of distinct values within a given series.

# %%
# What are the unique colors for the products?

# %%
# how many distinct colors are there?

# %%
# We can also include nulls with .nunique() as such:

# %% [markdown]
# ## Filtering on a Single Condition
#
# Filtering and sorting are key processes that allow us to drill into the 'nitty gritty' and cross sections of our dataset.
#
# To filter, we use a process called **Boolean Filtering**, wherein we define a Boolean condition, and use that Boolean condition to filer on our DataFrame.

# %% [markdown]
# Recall: our given dataset has a column `Color`. Let's see if we can find all products that are `Black`. Let's take a look at the first 10 rows of the dataframe to see how it looks as-is:

# %%
# show the first 10 rows of the 'Color' column
prod.head(10)
# Out:
#                             Name   Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0
# 2                   Bearing Ball  BA-8327         0                  0
# 3                BB Ball Bearing  BE-2349         1                  0
# 4          Headset Ball Bearings  BE-2908         0                  0
# 316                        Blade  BL-2036         1                  0
# 317                  LL Crankarm  CA-5965         0                  0
# 318                  ML Crankarm  CA-6738         0                  0
# 319                  HL Crankarm  CA-7457         0                  0
# 320              Chainring Bolts  CB-2903         0                  0
# 321                Chainring Nut  CN-6137         0                  0
#
#             Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 1             NaN              1000           750           0.0        0.0
# 2             NaN              1000           750           0.0        0.0
# 3             NaN               800           600           0.0        0.0
# 4             NaN               800           600           0.0        0.0
# 316           NaN               800           600           0.0        0.0
# 317         Black               500           375           0.0        0.0
# 318         Black               500           375           0.0        0.0
# 319         Black               500           375           0.0        0.0
# 320        Silver              1000           750           0.0        0.0
# 321        Silver              1000           750           0.0        0.0
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 1          NaN  ...         NaN   NaN    NaN                   NaN
# 2          NaN  ...         NaN   NaN    NaN                   NaN
# 3          NaN  ...         NaN   NaN    NaN                   NaN
# 4          NaN  ...         NaN   NaN    NaN                   NaN
# 316        NaN  ...         NaN   NaN    NaN                   NaN
# 317        NaN  ...         NaN    L     NaN                   NaN
# 318        NaN  ...         NaN    M     NaN                   NaN
# 319        NaN  ...         NaN   NaN    NaN                   NaN
# 320        NaN  ...         NaN   NaN    NaN                   NaN
# 321        NaN  ...         NaN   NaN    NaN                   NaN
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1                    NaN  2008-04-30 00:00:00         NaN               NaN
# 2                    NaN  2008-04-30 00:00:00         NaN               NaN
# 3                    NaN  2008-04-30 00:00:00         NaN               NaN
# 4                    NaN  2008-04-30 00:00:00         NaN               NaN
# 316                  NaN  2008-04-30 00:00:00         NaN               NaN
# 317                  NaN  2008-04-30 00:00:00         NaN               NaN
# 318                  NaN  2008-04-30 00:00:00         NaN               NaN
# 319                  NaN  2008-04-30 00:00:00         NaN               NaN
# 320                  NaN  2008-04-30 00:00:00         NaN               NaN
# 321                  NaN  2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 320        {7BE38E48-B7D6-4486-888E-F53C26735101}
# 321        {3314B1D7-EF69-4431-B6DD-DC75268BD5DF}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
# 317        2014-02-08 10:01:36.827000000
# 318        2014-02-08 10:01:36.827000000
# 319        2014-02-08 10:01:36.827000000
# 320        2014-02-08 10:01:36.827000000
# 321        2014-02-08 10:01:36.827000000
#
# [10 rows x 24 columns]

# %%
prod[["Color"]].head(10)
# Out:
#             Color
# ProductID
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 316           NaN
# 317         Black
# 318         Black
# 319         Black
# 320        Silver
# 321        Silver

# %% [markdown]
# By applying a `boolean mask` to this dataframe, `== 'Black'`, we can get the following:

# %%
# set the previous output to == Black
prod[prod["Color"] == "Black"]
# Out:
#                                     Name      Number  MakeFlag  \
# ProductID
# 317                          LL Crankarm     CA-5965         0
# 318                          ML Crankarm     CA-6738         0
# 319                          HL Crankarm     CA-7457         0
# 322                            Chainring     CR-7833         0
# 680            HL Road Frame - Black, 58  FR-R92B-58         1
# 708              Sport-100 Helmet, Black     HL-U509         0
# 722            LL Road Frame - Black, 58  FR-R38B-58         1
# 723            LL Road Frame - Black, 60  FR-R38B-60         1
# 724            LL Road Frame - Black, 62  FR-R38B-62         1
# 736            LL Road Frame - Black, 44  FR-R38B-44         1
# 737            LL Road Frame - Black, 48  FR-R38B-48         1
# 738            LL Road Frame - Black, 52  FR-R38B-52         1
# 743        HL Mountain Frame - Black, 42  FR-M94B-42         1
# 744        HL Mountain Frame - Black, 44  FR-M94B-44         1
# 745        HL Mountain Frame - Black, 48  FR-M94B-48         1
# 746        HL Mountain Frame - Black, 46  FR-M94B-46         1
# 747        HL Mountain Frame - Black, 38  FR-M94B-38         1
# 765                   Road-650 Black, 58  BK-R50B-58         1
# 766                   Road-650 Black, 60  BK-R50B-60         1
# 767                   Road-650 Black, 62  BK-R50B-62         1
# 768                   Road-650 Black, 44  BK-R50B-44         1
# 769                   Road-650 Black, 48  BK-R50B-48         1
# 770                   Road-650 Black, 52  BK-R50B-52         1
# 775               Mountain-100 Black, 38  BK-M82B-38         1
# 776               Mountain-100 Black, 42  BK-M82B-42         1
# 777               Mountain-100 Black, 44  BK-M82B-44         1
# 778               Mountain-100 Black, 48  BK-M82B-48         1
# 782               Mountain-200 Black, 38  BK-M68B-38         1
# 783               Mountain-200 Black, 42  BK-M68B-42         1
# 784               Mountain-200 Black, 46  BK-M68B-46         1
# ...                                  ...         ...       ...
# 851              Men's Sports Shorts, XL   SH-M897-X         0
# 852                    Women's Tights, S   TG-W091-S         0
# 853                    Women's Tights, M   TG-W091-M         0
# 854                    Women's Tights, L   TG-W091-L         0
# 858                Half-Finger Gloves, S   GL-H102-S         0
# 859                Half-Finger Gloves, M   GL-H102-M         0
# 860                Half-Finger Gloves, L   GL-H102-L         0
# 861                Full-Finger Gloves, S   GL-F110-S         0
# 862                Full-Finger Gloves, M   GL-F110-M         0
# 863                Full-Finger Gloves, L   GL-F110-L         0
# 867           Women's Mountain Shorts, S   SH-W890-S         0
# 868           Women's Mountain Shorts, M   SH-W890-M         0
# 869           Women's Mountain Shorts, L   SH-W890-L         0
# 924        LL Mountain Frame - Black, 42  FR-M21B-42         1
# 925        LL Mountain Frame - Black, 44  FR-M21B-44         1
# 926        LL Mountain Frame - Black, 48  FR-M21B-48         1
# 927        LL Mountain Frame - Black, 52  FR-M21B-52         1
# 943        LL Mountain Frame - Black, 40  FR-M21B-40         1
# 949                          LL Crankset     CS-4759         1
# 950                          ML Crankset     CS-6583         1
# 951                          HL Crankset     CS-9183         1
# 977                   Road-750 Black, 58  BK-R19B-58         1
# 989               Mountain-500 Black, 40  BK-M18B-40         1
# 990               Mountain-500 Black, 42  BK-M18B-42         1
# 991               Mountain-500 Black, 44  BK-M18B-44         1
# 992               Mountain-500 Black, 48  BK-M18B-48         1
# 993               Mountain-500 Black, 52  BK-M18B-52         1
# 997                   Road-750 Black, 44  BK-R19B-44         1
# 998                   Road-750 Black, 48  BK-R19B-48         1
# 999                   Road-750 Black, 52  BK-R19B-52         1
#
#            FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  \
# ProductID
# 317                        0  Black               500           375
# 318                        0  Black               500           375
# 319                        0  Black               500           375
# 322                        0  Black              1000           750
# 680                        1  Black               500           375
# 708                        1  Black                 4             3
# 722                        1  Black               500           375
# 723                        1  Black               500           375
# 724                        1  Black               500           375
# 736                        1  Black               500           375
# 737                        1  Black               500           375
# 738                        1  Black               500           375
# 743                        1  Black               500           375
# 744                        1  Black               500           375
# 745                        1  Black               500           375
# 746                        1  Black               500           375
# 747                        1  Black               500           375
# 765                        1  Black               100            75
# 766                        1  Black               100            75
# 767                        1  Black               100            75
# 768                        1  Black               100            75
# 769                        1  Black               100            75
# 770                        1  Black               100            75
# 775                        1  Black               100            75
# 776                        1  Black               100            75
# 777                        1  Black               100            75
# 778                        1  Black               100            75
# 782                        1  Black               100            75
# 783                        1  Black               100            75
# 784                        1  Black               100            75
# ...                      ...    ...               ...           ...
# 851                        1  Black                 4             3
# 852                        1  Black                 4             3
# 853                        1  Black                 4             3
# 854                        1  Black                 4             3
# 858                        1  Black                 4             3
# 859                        1  Black                 4             3
# 860                        1  Black                 4             3
# 861                        1  Black                 4             3
# 862                        1  Black                 4             3
# 863                        1  Black                 4             3
# 867                        1  Black                 4             3
# 868                        1  Black                 4             3
# 869                        1  Black                 4             3
# 924                        1  Black               500           375
# 925                        1  Black               500           375
# 926                        1  Black               500           375
# 927                        1  Black               500           375
# 943                        1  Black               500           375
# 949                        1  Black               500           375
# 950                        1  Black               500           375
# 951                        1  Black               500           375
# 977                        1  Black               100            75
# 989                        1  Black               100            75
# 990                        1  Black               100            75
# 991                        1  Black               100            75
# 992                        1  Black               100            75
# 993                        1  Black               100            75
# 997                        1  Black               100            75
# 998                        1  Black               100            75
# 999                        1  Black               100            75
#
#            StandardCost  ListPrice Size  ... ProductLine Class  Style  \
# ProductID                                ...
# 317              0.0000       0.00  NaN  ...         NaN    L     NaN
# 318              0.0000       0.00  NaN  ...         NaN    M     NaN
# 319              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 322              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 680           1059.3100    1431.50   58  ...          R     H      U
# 708             13.0863      34.99  NaN  ...          S    NaN    NaN
# 722            204.6251     337.22   58  ...          R     L      U
# 723            204.6251     337.22   60  ...          R     L      U
# 724            204.6251     337.22   62  ...          R     L      U
# 736            204.6251     337.22   44  ...          R     L      U
# 737            204.6251     337.22   48  ...          R     L      U
# 738            204.6251     337.22   52  ...          R     L      U
# 743            739.0410    1349.60   42  ...          M     H      U
# 744            699.0928    1349.60   44  ...          M     H      U
# 745            699.0928    1349.60   48  ...          M     H      U
# 746            739.0410    1349.60   46  ...          M     H      U
# 747            739.0410    1349.60   38  ...          M     H      U
# 765            486.7066     782.99   58  ...          R     L      U
# 766            486.7066     782.99   60  ...          R     L      U
# 767            486.7066     782.99   62  ...          R     L      U
# 768            486.7066     782.99   44  ...          R     L      U
# 769            486.7066     782.99   48  ...          R     L      U
# 770            486.7066     782.99   52  ...          R     L      U
# 775           1898.0944    3374.99   38  ...          M     H      U
# 776           1898.0944    3374.99   42  ...          M     H      U
# 777           1898.0944    3374.99   44  ...          M     H      U
# 778           1898.0944    3374.99   48  ...          M     H      U
# 782           1251.9813    2294.99   38  ...          M     H      U
# 783           1251.9813    2294.99   42  ...          M     H      U
# 784           1251.9813    2294.99   46  ...          M     H      U
# ...                 ...        ...  ...  ...         ...   ...    ...
# 851             24.7459      59.99   XL  ...          S    NaN     M
# 852             30.9334      74.99    S  ...          S    NaN     W
# 853             30.9334      74.99    M  ...          S    NaN     W
# 854             30.9334      74.99    L  ...          S    NaN     W
# 858              9.1593      24.49    S  ...          S    NaN     U
# 859              9.1593      24.49    M  ...          S    NaN     U
# 860              9.1593      24.49    L  ...          S    NaN     U
# 861             15.6709      37.99    S  ...          M    NaN     U
# 862             15.6709      37.99    M  ...          M    NaN     U
# 863             15.6709      37.99    L  ...          M    NaN     U
# 867             26.1763      69.99    S  ...          M    NaN     W
# 868             26.1763      69.99    M  ...          M    NaN     W
# 869             26.1763      69.99    L  ...          M    NaN     W
# 924            136.7850     249.79   42  ...          M     L      U
# 925            136.7850     249.79   44  ...          M     L      U
# 926            136.7850     249.79   48  ...          M     L      U
# 927            136.7850     249.79   52  ...          M     L      U
# 943            136.7850     249.79   40  ...          M     L      U
# 949             77.9176     175.49  NaN  ...         NaN    L     NaN
# 950            113.8816     256.49  NaN  ...         NaN    M     NaN
# 951            179.8156     404.99  NaN  ...         NaN    H     NaN
# 977            343.6496     539.99   58  ...          R     L      U
# 989            294.5797     539.99   40  ...          M     L      U
# 990            294.5797     539.99   42  ...          M     L      U
# 991            294.5797     539.99   44  ...          M     L      U
# 992            294.5797     539.99   48  ...          M     L      U
# 993            294.5797     539.99   52  ...          M     L      U
# 997            343.6496     539.99   44  ...          R     L      U
# 998            343.6496     539.99   48  ...          R     L      U
# 999            343.6496     539.99   52  ...          R     L      U
#
#            ProductSubcategoryID ProductModelID        SellStartDate  \
# ProductID
# 317                         NaN            NaN  2008-04-30 00:00:00
# 318                         NaN            NaN  2008-04-30 00:00:00
# 319                         NaN            NaN  2008-04-30 00:00:00
# 322                         NaN            NaN  2008-04-30 00:00:00
# 680                        14.0            6.0  2008-04-30 00:00:00
# 708                        31.0           33.0  2011-05-31 00:00:00
# 722                        14.0            9.0  2011-05-31 00:00:00
# 723                        14.0            9.0  2011-05-31 00:00:00
# 724                        14.0            9.0  2011-05-31 00:00:00
# 736                        14.0            9.0  2011-05-31 00:00:00
# 737                        14.0            9.0  2011-05-31 00:00:00
# 738                        14.0            9.0  2011-05-31 00:00:00
# 743                        12.0            5.0  2011-05-31 00:00:00
# 744                        12.0            5.0  2011-05-31 00:00:00
# 745                        12.0            5.0  2011-05-31 00:00:00
# 746                        12.0            5.0  2011-05-31 00:00:00
# 775        2012-05-29 00:00:00               NaN
# 776        2012-05-29 00:00:00               NaN
# 777        2012-05-29 00:00:00               NaN
# 778        2012-05-29 00:00:00               NaN
# 782                        NaN               NaN
# 783                        NaN               NaN
# 784                        NaN               NaN
# ...                        ...               ...
# 851        2013-05-29 00:00:00               NaN
# 852        2013-05-29 00:00:00               NaN
# 853        2013-05-29 00:00:00               NaN
# 854        2013-05-29 00:00:00               NaN
# 858                        NaN               NaN
# 859                        NaN               NaN
# 860                        NaN               NaN
# 861        2013-05-29 00:00:00               NaN
# 862        2013-05-29 00:00:00               NaN
# 863        2013-05-29 00:00:00               NaN
# 867                        NaN               NaN
# 868                        NaN               NaN
# 869                        NaN               NaN
# 924                        NaN               NaN
# 925                        NaN               NaN
# 926                        NaN               NaN
# 927                        NaN               NaN
# 943                        NaN               NaN
# 949                        NaN               NaN
# 950                        NaN               NaN
# 951                        NaN               NaN
# 977                        NaN               NaN
# 989                        NaN               NaN
# 990                        NaN               NaN
# 991                        NaN               NaN
# 992                        NaN               NaN
# 993                        NaN               NaN
# 997                        NaN               NaN
# 998                        NaN               NaN
# 999                        NaN               NaN
#
#                                           rowguid  \
# ProductID
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 322        {F0AC2C4D-1A1F-4E3C-B4D9-68AEA0EC1CE4}
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# 708        {A25A44FB-C2DE-4268-958F-110B8D7621E2}
# 722        {2140F256-F705-4D67-975D-32DE03265838}
# 723        {AA95E2A5-E7C4-4B74-B1EA-B52EE3B51537}
# 724        {5247BE33-50BF-4527-8A30-A39AAE500A8E}
# 736        {C9967889-F490-4A66-943A-BCE432E938D8}
# 737        {3B5F29B6-A441-4FF7-A0FA-FAD10E2CEB4C}
# 738        {18FC5D72-A012-4DC7-BB35-0D01A84D0219}
# 743        {27DB28F8-5AB8-4091-B94E-6F1B2D8E7AB0}
# 744        {CB443286-6B25-409F-A10B-1AD4EEB4BD4E}
# 745        {1FEE0573-6676-432D-8D6D-41BA9FAA5865}
# 746        {50ABEBCB-451E-42B9-8DBB-E5C4A34470E9}
# 747        {0C548577-3171-4CE2-B9A0-1ED526849DE8}
# 765        {74645B12-3CE9-49A6-BD96-2CD814B37420}
# 766        {A2DB196D-6640-49EA-A84F-2E87CA6F50C6}
# 767        {C82A8309-63D3-4C0C-AD71-E91272397095}
# 768        {11D563AC-115C-4F0D-A1E5-E946EEE8B38B}
# 769        {A7E2179E-137C-497E-A5E6-C9EA64935FB0}
# 770        {136E2865-E0DA-4624-963A-31349279AB1A}
# 775        {DEA33347-FCD3-4346-AA0F-068CD6B3AD06}
# 776        {02935111-A546-4C6D-941F-BE12D42C158E}
# 777        {7920BC3B-8FD4-4610-93D2-E693A66B6474}
# 778        {1B486300-7E64-4C5D-A9BA-A8368E20C5A0}
# 782        {82CB8F9B-B8BB-4841-98D3-BCDB807C4DD8}
# 769        2014-02-08 10:01:36.827000000
# 770        2014-02-08 10:01:36.827000000
# 775        2014-02-08 10:01:36.827000000
# 776        2014-02-08 10:01:36.827000000
# 777        2014-02-08 10:01:36.827000000
# 778        2014-02-08 10:01:36.827000000
# 782        2014-02-08 10:01:36.827000000
# 783        2014-02-08 10:01:36.827000000
# 784        2014-02-08 10:01:36.827000000
# ...                                  ...
# 851        2014-02-08 10:01:36.827000000
# 852        2014-02-08 10:01:36.827000000
# 853        2014-02-08 10:01:36.827000000
# 854        2014-02-08 10:01:36.827000000
# 858        2014-02-08 10:01:36.827000000
# 859        2014-02-08 10:01:36.827000000
# 860        2014-02-08 10:01:36.827000000
# 861        2014-02-08 10:01:36.827000000
# 862        2014-02-08 10:01:36.827000000
# 863        2014-02-08 10:01:36.827000000
# 867        2014-02-08 10:01:36.827000000
# 868        2014-02-08 10:01:36.827000000
# 869        2014-02-08 10:01:36.827000000
# 924        2014-02-08 10:01:36.827000000
# 925        2014-02-08 10:01:36.827000000
# 926        2014-02-08 10:01:36.827000000
# 927        2014-02-08 10:01:36.827000000
# 943        2014-02-08 10:01:36.827000000
# 949        2014-02-08 10:01:36.827000000
# 950        2014-02-08 10:01:36.827000000
# 951        2014-02-08 10:01:36.827000000
# 977        2014-02-08 10:01:36.827000000
# 989        2014-02-08 10:01:36.827000000
# 990        2014-02-08 10:01:36.827000000
# 991        2014-02-08 10:01:36.827000000
# 992        2014-02-08 10:01:36.827000000
# 993        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [93 rows x 24 columns]

# %% [markdown]
# Now we can use that 'mask' from above, and apply it to our full dataframe. Every time we have a `True` in a row, we return the row. If we have a `False` in that row, we do not return it. The result is a dataframe that only has rows where `Color` is `Black`:

# %%
# show the full prod DataFrame where Color is Black
prod[prod["Color"] == "Black"][["Name", "Number"]]
# Out:
#                                     Name      Number
# ProductID
# 317                          LL Crankarm     CA-5965
# 318                          ML Crankarm     CA-6738
# 319                          HL Crankarm     CA-7457
# 322                            Chainring     CR-7833
# 680            HL Road Frame - Black, 58  FR-R92B-58
# 708              Sport-100 Helmet, Black     HL-U509
# 722            LL Road Frame - Black, 58  FR-R38B-58
# 723            LL Road Frame - Black, 60  FR-R38B-60
# 724            LL Road Frame - Black, 62  FR-R38B-62
# 736            LL Road Frame - Black, 44  FR-R38B-44
# 737            LL Road Frame - Black, 48  FR-R38B-48
# 738            LL Road Frame - Black, 52  FR-R38B-52
# 743        HL Mountain Frame - Black, 42  FR-M94B-42
# 744        HL Mountain Frame - Black, 44  FR-M94B-44
# 745        HL Mountain Frame - Black, 48  FR-M94B-48
# 746        HL Mountain Frame - Black, 46  FR-M94B-46
# 747        HL Mountain Frame - Black, 38  FR-M94B-38
# 765                   Road-650 Black, 58  BK-R50B-58
# 766                   Road-650 Black, 60  BK-R50B-60
# 767                   Road-650 Black, 62  BK-R50B-62
# 768                   Road-650 Black, 44  BK-R50B-44
# 769                   Road-650 Black, 48  BK-R50B-48
# 770                   Road-650 Black, 52  BK-R50B-52
# 775               Mountain-100 Black, 38  BK-M82B-38
# 776               Mountain-100 Black, 42  BK-M82B-42
# 777               Mountain-100 Black, 44  BK-M82B-44
# 778               Mountain-100 Black, 48  BK-M82B-48
# 782               Mountain-200 Black, 38  BK-M68B-38
# 783               Mountain-200 Black, 42  BK-M68B-42
# 784               Mountain-200 Black, 46  BK-M68B-46
# ...                                  ...         ...
# 851              Men's Sports Shorts, XL   SH-M897-X
# 852                    Women's Tights, S   TG-W091-S
# 853                    Women's Tights, M   TG-W091-M
# 854                    Women's Tights, L   TG-W091-L
# 858                Half-Finger Gloves, S   GL-H102-S
# 859                Half-Finger Gloves, M   GL-H102-M
# 860                Half-Finger Gloves, L   GL-H102-L
# 861                Full-Finger Gloves, S   GL-F110-S
# 862                Full-Finger Gloves, M   GL-F110-M
# 863                Full-Finger Gloves, L   GL-F110-L
# 867           Women's Mountain Shorts, S   SH-W890-S
# 868           Women's Mountain Shorts, M   SH-W890-M
# 869           Women's Mountain Shorts, L   SH-W890-L
# 924        LL Mountain Frame - Black, 42  FR-M21B-42
# 925        LL Mountain Frame - Black, 44  FR-M21B-44
# 926        LL Mountain Frame - Black, 48  FR-M21B-48
# 927        LL Mountain Frame - Black, 52  FR-M21B-52
# 943        LL Mountain Frame - Black, 40  FR-M21B-40
# 949                          LL Crankset     CS-4759
# 950                          ML Crankset     CS-6583
# 951                          HL Crankset     CS-9183
# 977                   Road-750 Black, 58  BK-R19B-58
# 989               Mountain-500 Black, 40  BK-M18B-40
# 990               Mountain-500 Black, 42  BK-M18B-42
# 991               Mountain-500 Black, 44  BK-M18B-44
# 992               Mountain-500 Black, 48  BK-M18B-48
# 993               Mountain-500 Black, 52  BK-M18B-52
# 997                   Road-750 Black, 44  BK-R19B-44
# 998                   Road-750 Black, 48  BK-R19B-48
# 999                   Road-750 Black, 52  BK-R19B-52
#
# [93 rows x 2 columns]

# %% [markdown]
# Let's calculate the **average ListPrice** for the **salable products**.

# %% [markdown]
# > Think: What are the component parts of this problem?

# %%
# First, we need to get salable items. 
# Use your data dictionary from the beginning of this lesson.
salable = prod[prod["FinishedGoodsFlag"] == 1]

# %%
prod.head()
# Out:
#                            Name1  Number1  MakeFlag1  FinishedGoodsFlag1  \
# ProductID
# 1                Adjustable Race  AR-5381          0                   0
# 2                   Bearing Ball  BA-8327          0                   0
# 3                BB Ball Bearing  BE-2349          1                   0
# 4          Headset Ball Bearings  BE-2908          0                   0
# 316                        Blade  BL-2036          1                   0
#
#           Color1  SafetyStockLevel1  ReorderPoint1  StandardCost1  ListPrice1  \
# ProductID
# 1            NaN               1000            750            0.0         0.0
# 2            NaN               1000            750            0.0         0.0
# 3            NaN                800            600            0.0         0.0
# 4            NaN                800            600            0.0         0.0
# 316          NaN                800            600            0.0         0.0
#
#           Size1  ... ProductLine1 Class1  Style1  ProductSubcategoryID1  \
# ProductID        ...
# 1           NaN  ...          NaN    NaN     NaN                    NaN
# 2           NaN  ...          NaN    NaN     NaN                    NaN
# 3           NaN  ...          NaN    NaN     NaN                    NaN
# 4           NaN  ...          NaN    NaN     NaN                    NaN
# 316         NaN  ...          NaN    NaN     NaN                    NaN
#
#           ProductModelID1       SellStartDate1 SellEndDate1  \
# ProductID
# 1                     NaN  2008-04-30 00:00:00          NaN
# 2                     NaN  2008-04-30 00:00:00          NaN
# 3                     NaN  2008-04-30 00:00:00          NaN
# 4                     NaN  2008-04-30 00:00:00          NaN
# 316                   NaN  2008-04-30 00:00:00          NaN
#
#            DiscontinuedDate1                                rowguid1  \
# ProductID
# 1                        NaN  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2                        NaN  {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3                        NaN  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4                        NaN  {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316                      NaN  {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                            ModifiedDate1
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %% [markdown]
# Now, we need to find average list price of those above items. Let's just get the 'ListPrice' column for starters.

# %%
salable["ListPrice"].describe()
# Out:
# count     295.000000
# mean      744.595220
# std       892.563172
# min         2.290000
# 25%        66.745000
# 50%       337.220000
# 75%      1100.240000
# max      3578.270000
# Name: ListPrice, dtype: float64

# %% [markdown]
# To get the average of that column, just take `.mean()`

# %%
salable[salable["ListPrice"] > 3000]
# Out:
#                               Name      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 749               Road-150 Red, 62  BK-R93R-62         1                  1
# 750               Road-150 Red, 44  BK-R93R-44         1                  1
# 751               Road-150 Red, 48  BK-R93R-48         1                  1
# 752               Road-150 Red, 52  BK-R93R-52         1                  1
# 753               Road-150 Red, 56  BK-R93R-56         1                  1
# 771        Mountain-100 Silver, 38  BK-M82S-38         1                  1
# 772        Mountain-100 Silver, 42  BK-M82S-42         1                  1
# 773        Mountain-100 Silver, 44  BK-M82S-44         1                  1
# 774        Mountain-100 Silver, 48  BK-M82S-48         1                  1
# 775         Mountain-100 Black, 38  BK-M82B-38         1                  1
# 776         Mountain-100 Black, 42  BK-M82B-42         1                  1
# 777         Mountain-100 Black, 44  BK-M82B-44         1                  1
# 778         Mountain-100 Black, 48  BK-M82B-48         1                  1
#
#             Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 749           Red               100            75     2171.2942    3578.27
# 750           Red               100            75     2171.2942    3578.27
# 751           Red               100            75     2171.2942    3578.27
# 752           Red               100            75     2171.2942    3578.27
# 753           Red               100            75     2171.2942    3578.27
# 771        Silver               100            75     1912.1544    3399.99
# 772        Silver               100            75     1912.1544    3399.99
# 773        Silver               100            75     1912.1544    3399.99
# 774        Silver               100            75     1912.1544    3399.99
# 775         Black               100            75     1898.0944    3374.99
# 776         Black               100            75     1898.0944    3374.99
# 777         Black               100            75     1898.0944    3374.99
# 778         Black               100            75     1898.0944    3374.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 749         62  ...          R     H      U                    2.0
# 750         44  ...          R     H      U                    2.0
# 751         48  ...          R     H      U                    2.0
# 752         52  ...          R     H      U                    2.0
# 753         56  ...          R     H      U                    2.0
# 771         38  ...          M     H      U                    1.0
# 772         42  ...          M     H      U                    1.0
# 773         44  ...          M     H      U                    1.0
# 774         48  ...          M     H      U                    1.0
# 775         38  ...          M     H      U                    1.0
# 776         42  ...          M     H      U                    1.0
# 777         44  ...          M     H      U                    1.0
# 778         48  ...          M     H      U                    1.0
#
#           ProductModelID        SellStartDate          SellEndDate  \
# ProductID
# 749                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 750                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 751                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 752                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 753                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 771                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 772                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 773                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 774                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 775                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 776                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 777                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 778                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
#
#            DiscontinuedDate                                 rowguid  \
# ProductID
# 749                     NaN  {BC621E1F-2553-4FDC-B22E-5E44A9003569}
# 750                     NaN  {C19E1136-5DA4-4B40-8758-54A85D7EA494}
# 751                     NaN  {D10B7CC1-455E-435B-A08F-EC5B1C5776E9}
# 752                     NaN  {5E085BA0-3CD5-487F-85BB-79ED1C701F23}
# 753                     NaN  {30819B88-F0D3-4E7A-8105-19F6FAC2CEFB}
# 771                     NaN  {CA74B54E-FC30-4464-8B83-019BFD1B2DBB}
# 772                     NaN  {BBFFF5A5-4BDC-49A9-A5AD-7584ADFFE808}
# 773                     NaN  {155FD77E-D6D6-43F0-8A5B-4A8305EB45CD}
# 774                     NaN  {BA5551DF-C9EE-4B43-B3CA-8C19D0F9384D}
# 775                     NaN  {DEA33347-FCD3-4346-AA0F-068CD6B3AD06}
# 776                     NaN  {02935111-A546-4C6D-941F-BE12D42C158E}
# 777                     NaN  {7920BC3B-8FD4-4610-93D2-E693A66B6474}
# 778                     NaN  {1B486300-7E64-4C5D-A9BA-A8368E20C5A0}
#
#                             ModifiedDate
# ProductID
# 749        2014-02-08 10:01:36.827000000
# 750        2014-02-08 10:01:36.827000000
# 751        2014-02-08 10:01:36.827000000
# 752        2014-02-08 10:01:36.827000000
# 753        2014-02-08 10:01:36.827000000
# 771        2014-02-08 10:01:36.827000000
# 772        2014-02-08 10:01:36.827000000
# 773        2014-02-08 10:01:36.827000000
# 774        2014-02-08 10:01:36.827000000
# 775        2014-02-08 10:01:36.827000000
# 776        2014-02-08 10:01:36.827000000
# 777        2014-02-08 10:01:36.827000000
# 778        2014-02-08 10:01:36.827000000
#
# [13 rows x 24 columns]

# %% [markdown]
# We can take a shortcut and just use `.describe()` here:

# %% [markdown]
# **Sneak peek**: Another handy trick is to use `.hist()` to get a distribution of a continuous variable - in this case, `ListPrice`. We'll cover this more in future lessons:

# %%
salable["ListPrice"].hist()

# %% [markdown]
# ## Filtering on Multiple Conditions
#
# Here, we will filter on _multiple conditions_. Before, we filtered on rows where Color was Black. We also filtered where FinishedGoodsFlag was equal to 1. Let's see what happens when we filter on *both* simultaneously.
#
# The format for multiple conditions is:
#
# `df[ (df['col1'] == value1) & (df['col2'] == value2) ]`
#
# Or, more simply:
#
# `df[ (CONDITION 1) & (CONDITION 2) ]`
#
# Which eventually may evaluate to something like:
#
# `df[ True & False ]`
#
# ...on a row-by-row basis. If the end result is `False`, the row is omitted.
#
# _Don't forget parentheses in your conditions!_ This is a common mistake.

# %%
# Let's look at a table where Color is Black, AND FinishedGoodsFlag is 1
black = prod["Color"] == "Black"
finished = prod["FinishedGoodsFlag"] == 1
prod[(black) & (finished)]
# Out:
#                                     Name      Number  MakeFlag  \
# ProductID
# 680            HL Road Frame - Black, 58  FR-R92B-58         1
# 708              Sport-100 Helmet, Black     HL-U509         0
# 722            LL Road Frame - Black, 58  FR-R38B-58         1
# 723            LL Road Frame - Black, 60  FR-R38B-60         1
# 724            LL Road Frame - Black, 62  FR-R38B-62         1
# 736            LL Road Frame - Black, 44  FR-R38B-44         1
# 737            LL Road Frame - Black, 48  FR-R38B-48         1
# 738            LL Road Frame - Black, 52  FR-R38B-52         1
# 743        HL Mountain Frame - Black, 42  FR-M94B-42         1
# 744        HL Mountain Frame - Black, 44  FR-M94B-44         1
# 745        HL Mountain Frame - Black, 48  FR-M94B-48         1
# 746        HL Mountain Frame - Black, 46  FR-M94B-46         1
# 747        HL Mountain Frame - Black, 38  FR-M94B-38         1
# 765                   Road-650 Black, 58  BK-R50B-58         1
# 766                   Road-650 Black, 60  BK-R50B-60         1
# 767                   Road-650 Black, 62  BK-R50B-62         1
# 768                   Road-650 Black, 44  BK-R50B-44         1
# 769                   Road-650 Black, 48  BK-R50B-48         1
# 770                   Road-650 Black, 52  BK-R50B-52         1
# 775               Mountain-100 Black, 38  BK-M82B-38         1
# 776               Mountain-100 Black, 42  BK-M82B-42         1
# 777               Mountain-100 Black, 44  BK-M82B-44         1
# 778               Mountain-100 Black, 48  BK-M82B-48         1
# 782               Mountain-200 Black, 38  BK-M68B-38         1
# 783               Mountain-200 Black, 42  BK-M68B-42         1
# 784               Mountain-200 Black, 46  BK-M68B-46         1
# 785               Mountain-300 Black, 38  BK-M47B-38         1
# 786               Mountain-300 Black, 40  BK-M47B-40         1
# 787               Mountain-300 Black, 44  BK-M47B-44         1
# 788               Mountain-300 Black, 48  BK-M47B-48         1
# ...                                  ...         ...       ...
# 851              Men's Sports Shorts, XL   SH-M897-X         0
# 852                    Women's Tights, S   TG-W091-S         0
# 853                    Women's Tights, M   TG-W091-M         0
# 854                    Women's Tights, L   TG-W091-L         0
# 858                Half-Finger Gloves, S   GL-H102-S         0
# 859                Half-Finger Gloves, M   GL-H102-M         0
# 860                Half-Finger Gloves, L   GL-H102-L         0
# 861                Full-Finger Gloves, S   GL-F110-S         0
# 862                Full-Finger Gloves, M   GL-F110-M         0
# 863                Full-Finger Gloves, L   GL-F110-L         0
# 867           Women's Mountain Shorts, S   SH-W890-S         0
# 868           Women's Mountain Shorts, M   SH-W890-M         0
# 869           Women's Mountain Shorts, L   SH-W890-L         0
# 924        LL Mountain Frame - Black, 42  FR-M21B-42         1
# 925        LL Mountain Frame - Black, 44  FR-M21B-44         1
# 926        LL Mountain Frame - Black, 48  FR-M21B-48         1
# 927        LL Mountain Frame - Black, 52  FR-M21B-52         1
# 943        LL Mountain Frame - Black, 40  FR-M21B-40         1
# 949                          LL Crankset     CS-4759         1
# 950                          ML Crankset     CS-6583         1
# 951                          HL Crankset     CS-9183         1
# 977                   Road-750 Black, 58  BK-R19B-58         1
# 989               Mountain-500 Black, 40  BK-M18B-40         1
# 990               Mountain-500 Black, 42  BK-M18B-42         1
# 991               Mountain-500 Black, 44  BK-M18B-44         1
# 992               Mountain-500 Black, 48  BK-M18B-48         1
# 993               Mountain-500 Black, 52  BK-M18B-52         1
# 997                   Road-750 Black, 44  BK-R19B-44         1
# 998                   Road-750 Black, 48  BK-R19B-48         1
# 999                   Road-750 Black, 52  BK-R19B-52         1
#
#            FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  \
# ProductID
# 680                        1  Black               500           375
# 708                        1  Black                 4             3
# 722                        1  Black               500           375
# 723                        1  Black               500           375
# 724                        1  Black               500           375
# 736                        1  Black               500           375
# 737                        1  Black               500           375
# 738                        1  Black               500           375
# 743                        1  Black               500           375
# 744                        1  Black               500           375
# 745                        1  Black               500           375
# 746                        1  Black               500           375
# 747                        1  Black               500           375
# 765                        1  Black               100            75
# 766                        1  Black               100            75
# 767                        1  Black               100            75
# 768                        1  Black               100            75
# 769                        1  Black               100            75
# 770                        1  Black               100            75
# 775                        1  Black               100            75
# 776                        1  Black               100            75
# 777                        1  Black               100            75
# 778                        1  Black               100            75
# 782                        1  Black               100            75
# 783                        1  Black               100            75
# 784                        1  Black               100            75
# 785                        1  Black               100            75
# 786                        1  Black               100            75
# 787                        1  Black               100            75
# 788                        1  Black               100            75
# ...                      ...    ...               ...           ...
# 851                        1  Black                 4             3
# 852                        1  Black                 4             3
# 853                        1  Black                 4             3
# 854                        1  Black                 4             3
# 858                        1  Black                 4             3
# 859                        1  Black                 4             3
# 860                        1  Black                 4             3
# 861                        1  Black                 4             3
# 862                        1  Black                 4             3
# 863                        1  Black                 4             3
# 867                        1  Black                 4             3
# 868                        1  Black                 4             3
# 869                        1  Black                 4             3
# 924                        1  Black               500           375
# 925                        1  Black               500           375
# 926                        1  Black               500           375
# 927                        1  Black               500           375
# 943                        1  Black               500           375
# 949                        1  Black               500           375
# 950                        1  Black               500           375
# 951                        1  Black               500           375
# 977                        1  Black               100            75
# 989                        1  Black               100            75
# 990                        1  Black               100            75
# 991                        1  Black               100            75
# 992                        1  Black               100            75
# 993                        1  Black               100            75
# 997                        1  Black               100            75
# 998                        1  Black               100            75
# 999                        1  Black               100            75
#
#            StandardCost  ListPrice Size  ... ProductLine Class  Style  \
# ProductID                                ...
# 680           1059.3100    1431.50   58  ...          R     H      U
# 708             13.0863      34.99  NaN  ...          S    NaN    NaN
# 722            204.6251     337.22   58  ...          R     L      U
# 723            204.6251     337.22   60  ...          R     L      U
# 724            204.6251     337.22   62  ...          R     L      U
# 736            204.6251     337.22   44  ...          R     L      U
# 737            204.6251     337.22   48  ...          R     L      U
# 738            204.6251     337.22   52  ...          R     L      U
# 743            739.0410    1349.60   42  ...          M     H      U
# 744            699.0928    1349.60   44  ...          M     H      U
# 745            699.0928    1349.60   48  ...          M     H      U
# 746            739.0410    1349.60   46  ...          M     H      U
# 747            739.0410    1349.60   38  ...          M     H      U
# 765            486.7066     782.99   58  ...          R     L      U
# 766            486.7066     782.99   60  ...          R     L      U
# 767            486.7066     782.99   62  ...          R     L      U
# 768            486.7066     782.99   44  ...          R     L      U
# 769            486.7066     782.99   48  ...          R     L      U
# 770            486.7066     782.99   52  ...          R     L      U
# 775           1898.0944    3374.99   38  ...          M     H      U
# 776           1898.0944    3374.99   42  ...          M     H      U
# 777           1898.0944    3374.99   44  ...          M     H      U
# 778           1898.0944    3374.99   48  ...          M     H      U
# 782           1251.9813    2294.99   38  ...          M     H      U
# 783           1251.9813    2294.99   42  ...          M     H      U
# 784           1251.9813    2294.99   46  ...          M     H      U
# 785            598.4354    1079.99   38  ...          M     M      U
# 786            598.4354    1079.99   40  ...          M     M      U
# 787            598.4354    1079.99   44  ...          M     M      U
# 788            598.4354    1079.99   48  ...          M     M      U
# ...                 ...        ...  ...  ...         ...   ...    ...
# 851             24.7459      59.99   XL  ...          S    NaN     M
# 852             30.9334      74.99    S  ...          S    NaN     W
# 853             30.9334      74.99    M  ...          S    NaN     W
# 854             30.9334      74.99    L  ...          S    NaN     W
# 858              9.1593      24.49    S  ...          S    NaN     U
# 859              9.1593      24.49    M  ...          S    NaN     U
# 860              9.1593      24.49    L  ...          S    NaN     U
# 861             15.6709      37.99    S  ...          M    NaN     U
# 862             15.6709      37.99    M  ...          M    NaN     U
# 863             15.6709      37.99    L  ...          M    NaN     U
# 867             26.1763      69.99    S  ...          M    NaN     W
# 868             26.1763      69.99    M  ...          M    NaN     W
# 869             26.1763      69.99    L  ...          M    NaN     W
# 924            136.7850     249.79   42  ...          M     L      U
# 925            136.7850     249.79   44  ...          M     L      U
# 926            136.7850     249.79   48  ...          M     L      U
# 927            136.7850     249.79   52  ...          M     L      U
# 943            136.7850     249.79   40  ...          M     L      U
# 927                        12.0            8.0  2013-05-30 00:00:00
# 943                        12.0            8.0  2013-05-30 00:00:00
# 949                         8.0           99.0  2013-05-30 00:00:00
# 950                         8.0          100.0  2013-05-30 00:00:00
# 951                         8.0          101.0  2013-05-30 00:00:00
# 977                         2.0           31.0  2013-05-30 00:00:00
# 989                         1.0           23.0  2013-05-30 00:00:00
# 990                         1.0           23.0  2013-05-30 00:00:00
# 991                         1.0           23.0  2013-05-30 00:00:00
# 992                         1.0           23.0  2013-05-30 00:00:00
# 993                         1.0           23.0  2013-05-30 00:00:00
# 997                         2.0           31.0  2013-05-30 00:00:00
# 998                         2.0           31.0  2013-05-30 00:00:00
# 999                         2.0           31.0  2013-05-30 00:00:00
#
#                    SellEndDate  DiscontinuedDate  \
# ProductID
# 680                        NaN               NaN
# 708                        NaN               NaN
# 722                        NaN               NaN
# 723                        NaN               NaN
# 724                        NaN               NaN
# 736                        NaN               NaN
# 737                        NaN               NaN
# 738                        NaN               NaN
# 743                        NaN               NaN
# 744        2012-05-29 00:00:00               NaN
# 745        2012-05-29 00:00:00               NaN
# 746                        NaN               NaN
# 747                        NaN               NaN
# 765        2013-05-29 00:00:00               NaN
# 766        2013-05-29 00:00:00               NaN
# 767        2013-05-29 00:00:00               NaN
# 768        2013-05-29 00:00:00               NaN
# 769        2013-05-29 00:00:00               NaN
# 770        2013-05-29 00:00:00               NaN
# 775        2012-05-29 00:00:00               NaN
# 776        2012-05-29 00:00:00               NaN
# 777        2012-05-29 00:00:00               NaN
# 778        2012-05-29 00:00:00               NaN
# 782                        NaN               NaN
# 783                        NaN               NaN
# 784                        NaN               NaN
# 785        2013-05-29 00:00:00               NaN
# 786        2013-05-29 00:00:00               NaN
# 787        2013-05-29 00:00:00               NaN
# 788        2013-05-29 00:00:00               NaN
# ...                        ...               ...
# 851        2013-05-29 00:00:00               NaN
# 852        2013-05-29 00:00:00               NaN
# 853        2013-05-29 00:00:00               NaN
# 854        2013-05-29 00:00:00               NaN
# 858                        NaN               NaN
# 859                        NaN               NaN
# 860                        NaN               NaN
# 861        2013-05-29 00:00:00               NaN
# 862        2013-05-29 00:00:00               NaN
# 863        2013-05-29 00:00:00               NaN
# 867                        NaN               NaN
# 868                        NaN               NaN
# 869                        NaN               NaN
# 924                        NaN               NaN
# 925                        NaN               NaN
# 926                        NaN               NaN
# 927                        NaN               NaN
# 943                        NaN               NaN
# 949                        NaN               NaN
# 950                        NaN               NaN
# 951                        NaN               NaN
# 977                        NaN               NaN
# 989                        NaN               NaN
# 990                        NaN               NaN
# 991                        NaN               NaN
# 992                        NaN               NaN
# 993                        NaN               NaN
# 997                        NaN               NaN
# 998                        NaN               NaN
# 999                        NaN               NaN
#
#                                           rowguid  \
# ProductID
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# 708        {A25A44FB-C2DE-4268-958F-110B8D7621E2}
# 722        {2140F256-F705-4D67-975D-32DE03265838}
# 723        {AA95E2A5-E7C4-4B74-B1EA-B52EE3B51537}
# 724        {5247BE33-50BF-4527-8A30-A39AAE500A8E}
# 992         Black               100            75      294.5797     539.99
# 993         Black               100            75      294.5797     539.99
# 994           NaN               500           375       23.9716      53.99
# 995           NaN               500           375       44.9506     101.24
# 996           NaN               500           375       53.9416     121.49
# 997         Black               100            75      343.6496     539.99
# 998         Black               100            75      343.6496     539.99
# 999         Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 1          NaN  ...         NaN   NaN    NaN                   NaN
# 2          NaN  ...         NaN   NaN    NaN                   NaN
# 3          NaN  ...         NaN   NaN    NaN                   NaN
# 4          NaN  ...         NaN   NaN    NaN                   NaN
# 316        NaN  ...         NaN   NaN    NaN                   NaN
# 317        NaN  ...         NaN    L     NaN                   NaN
# 318        NaN  ...         NaN    M     NaN                   NaN
# 319        NaN  ...         NaN   NaN    NaN                   NaN
# 320        NaN  ...         NaN   NaN    NaN                   NaN
# 321        NaN  ...         NaN   NaN    NaN                   NaN
# 322        NaN  ...         NaN   NaN    NaN                   NaN
# 323        NaN  ...         NaN   NaN    NaN                   NaN
# 324        NaN  ...         NaN   NaN    NaN                   NaN
# 325        NaN  ...         NaN   NaN    NaN                   NaN
# 326        NaN  ...         NaN   NaN    NaN                   NaN
# 327        NaN  ...         NaN   NaN    NaN                   NaN
# 328        NaN  ...         NaN   NaN    NaN                   NaN
# 329        NaN  ...         NaN   NaN    NaN                   NaN
# 330        NaN  ...         NaN   NaN    NaN                   NaN
# 331        NaN  ...         NaN   NaN    NaN                   NaN
# 332        NaN  ...         NaN   NaN    NaN                   NaN
# 341        NaN  ...         NaN   NaN    NaN                   NaN
# 342        NaN  ...         NaN   NaN    NaN                   NaN
# 343        NaN  ...         NaN   NaN    NaN                   NaN
# 344        NaN  ...         NaN   NaN    NaN                   NaN
# 345        NaN  ...         NaN   NaN    NaN                   NaN
# 346        NaN  ...         NaN   NaN    NaN                   NaN
# 347        NaN  ...         NaN   NaN    NaN                   NaN
# 348        NaN  ...         NaN   NaN    NaN                   NaN
# 349        NaN  ...         NaN   NaN    NaN                   NaN
# ...        ...  ...         ...   ...    ...                   ...
# 970         46  ...          T     M      U                    3.0
# 971         50  ...          T     M      U                    3.0
# 972         54  ...          T     M      U                    3.0
# 973         40  ...          R     M      W                    2.0
# 974         42  ...          R     M      W                    2.0
# 975         44  ...          R     M      W                    2.0
# 976         48  ...          R     M      W                    2.0
# 977         58  ...          R     L      U                    2.0
# 978         44  ...          T     L      U                    3.0
# 979         50  ...          T     L      U                    3.0
# 980         38  ...          M     M      W                    1.0
# 981         40  ...          M     M      W                    1.0
# 982         42  ...          M     M      W                    1.0
# 983         46  ...          M     M      W                    1.0
# 984         40  ...          M     L      U                    1.0
# 985         42  ...          M     L      U                    1.0
# 986         44  ...          M     L      U                    1.0
# 987         48  ...          M     L      U                    1.0
# 988         52  ...          M     L      U                    1.0
# 989         40  ...          M     L      U                    1.0
# 990         42  ...          M     L      U                    1.0
# 991         44  ...          M     L      U                    1.0
# 992         48  ...          M     L      U                    1.0
# 993         52  ...          M     L      U                    1.0
# 994        NaN  ...         NaN    L     NaN                   5.0
# 995        NaN  ...         NaN    M     NaN                   5.0
# 996        NaN  ...         NaN    H     NaN                   5.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1                    NaN  2008-04-30 00:00:00         NaN               NaN
# 2                    NaN  2008-04-30 00:00:00         NaN               NaN
# 3                    NaN  2008-04-30 00:00:00         NaN               NaN
# 4                    NaN  2008-04-30 00:00:00         NaN               NaN
# 316                  NaN  2008-04-30 00:00:00         NaN               NaN
# 317                  NaN  2008-04-30 00:00:00         NaN               NaN
# 318                  NaN  2008-04-30 00:00:00         NaN               NaN
# 319                  NaN  2008-04-30 00:00:00         NaN               NaN
# 320                  NaN  2008-04-30 00:00:00         NaN               NaN
# 321                  NaN  2008-04-30 00:00:00         NaN               NaN
# 322                  NaN  2008-04-30 00:00:00         NaN               NaN
# 323                  NaN  2008-04-30 00:00:00         NaN               NaN
# 324                  NaN  2008-04-30 00:00:00         NaN               NaN
# 325                  NaN  2008-04-30 00:00:00         NaN               NaN
# 326                  NaN  2008-04-30 00:00:00         NaN               NaN
# 327                  NaN  2008-04-30 00:00:00         NaN               NaN
# 328                  NaN  2008-04-30 00:00:00         NaN               NaN
# 329                  NaN  2008-04-30 00:00:00         NaN               NaN
# 330                  NaN  2008-04-30 00:00:00         NaN               NaN
# 331                  NaN  2008-04-30 00:00:00         NaN               NaN
# 332                  NaN  2008-04-30 00:00:00         NaN               NaN
# 341                  NaN  2008-04-30 00:00:00         NaN               NaN
# 342                  NaN  2008-04-30 00:00:00         NaN               NaN
# 343                  NaN  2008-04-30 00:00:00         NaN               NaN
# 344                  NaN  2008-04-30 00:00:00         NaN               NaN
# 345                  NaN  2008-04-30 00:00:00         NaN               NaN
# 346                  NaN  2008-04-30 00:00:00         NaN               NaN
# 347                  NaN  2008-04-30 00:00:00         NaN               NaN
# 348                  NaN  2008-04-30 00:00:00         NaN               NaN
# 349                  NaN  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 970                 35.0  2013-05-30 00:00:00         NaN               NaN
# 971                 35.0  2013-05-30 00:00:00         NaN               NaN
# 972                 35.0  2013-05-30 00:00:00         NaN               NaN
# 973                 27.0  2013-05-30 00:00:00         NaN               NaN
# 974                 27.0  2013-05-30 00:00:00         NaN               NaN
# 975                 27.0  2013-05-30 00:00:00         NaN               NaN
# 976                 27.0  2013-05-30 00:00:00         NaN               NaN
# 977                 31.0  2013-05-30 00:00:00         NaN               NaN
# 978                 36.0  2013-05-30 00:00:00         NaN               NaN
# 979                 36.0  2013-05-30 00:00:00         NaN               NaN
# 980                 22.0  2013-05-30 00:00:00         NaN               NaN
# 981                 22.0  2013-05-30 00:00:00         NaN               NaN
# 982                 22.0  2013-05-30 00:00:00         NaN               NaN
# 983                 22.0  2013-05-30 00:00:00         NaN               NaN
# 984                 23.0  2013-05-30 00:00:00         NaN               NaN
# 985                 23.0  2013-05-30 00:00:00         NaN               NaN
# 986                 23.0  2013-05-30 00:00:00         NaN               NaN
# 987                 23.0  2013-05-30 00:00:00         NaN               NaN
# 988                 23.0  2013-05-30 00:00:00         NaN               NaN
# 989                 23.0  2013-05-30 00:00:00         NaN               NaN
# 990                 23.0  2013-05-30 00:00:00         NaN               NaN
# 991                 23.0  2013-05-30 00:00:00         NaN               NaN
# 992                 23.0  2013-05-30 00:00:00         NaN               NaN
# 993                 23.0  2013-05-30 00:00:00         NaN               NaN
# 994                 95.0  2013-05-30 00:00:00         NaN               NaN
# 995                 96.0  2013-05-30 00:00:00         NaN               NaN
# 996                 97.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 320        {7BE38E48-B7D6-4486-888E-F53C26735101}
# 321        {3314B1D7-EF69-4431-B6DD-DC75268BD5DF}
# 322        {F0AC2C4D-1A1F-4E3C-B4D9-68AEA0EC1CE4}
# 323        {51A32CA6-65A1-4C31-AF2B-D9E4F5D631D4}
# 324        {FE0678ED-AEF2-4C58-A450-8151CC24DDD8}
# 325        {05CE123C-A402-478E-AE9B-75D7727AEAAD}
# 326        {A56851F9-1CD7-4E2F-8779-2E773E1B5209}
# 327        {1DAD47DD-E259-42B8-B8B4-15A0B7D21B2F}
# 328        {6070B1EA-59B7-4F8B-950F-2BE07D00449D}
# 329        {88399D13-719E-4545-81D6-F0650F372FA2}
# 330        {6903CE24-D0CE-4191-9198-4231DE37A929}
# 331        {C91D602E-DA52-43D2-BD7E-EB110A9392B9}
# 332        {D864879A-E8B1-4F7B-BAFA-1F136089C2C8}
# 341        {A3F2FA3A-22E1-43D8-A131-A9B89C32D8EA}
# 342        {331ADDEC-E9B9-4A7E-9324-42069C2DCDC4}
# 343        {84A3473E-AE26-4A21-81B9-60BB418A79B2}
# 344        {0AE4CE60-5242-48F5-ADA1-3013FF45F969}
# 345        {2C1C58B4-234C-4B3A-8C8E-84524AC05EEA}
# 346        {590C2C3F-A8B6-42B5-9412-D655E37F0EAE}
# 347        {1B73F5FE-AB85-49FC-99AD-0500CEBDA91D}
# 348        {D182CF18-4DDF-429B-A0DF-DE1CFC92622D}
# 349        {7E55F64D-EA3C-45FF-BE72-F7F7B9D61A79}
# ...                                           ...
# 796         Black               100            75     1554.9479    2443.35
# 795         Black               100            75     1554.9479    2443.35
# 790           Red               100            75     1518.7864    2443.35
# 789           Red               100            75     1518.7864    2443.35
# 791           Red               100            75     1518.7864    2443.35
# 966          Blue               100            75     1481.9379    2384.07
# 969          Blue               100            75     1481.9379    2384.07
# 954        Yellow               100            75     1481.9379    2384.07
# 955        Yellow               100            75     1481.9379    2384.07
# 956        Yellow               100            75     1481.9379    2384.07
# 968          Blue               100            75     1481.9379    2384.07
# 957        Yellow               100            75     1481.9379    2384.07
# 967          Blue               100            75     1481.9379    2384.07
# 781        Silver               100            75     1265.6195    2319.99
# ...           ...               ...           ...           ...        ...
# 430           NaN              1000           750        0.0000       0.00
# 432           NaN              1000           750        0.0000       0.00
# 405           NaN              1000           750        0.0000       0.00
# 433           NaN              1000           750        0.0000       0.00
# 434           NaN              1000           750        0.0000       0.00
# 435           NaN              1000           750        0.0000       0.00
# 436           NaN              1000           750        0.0000       0.00
# 437           NaN              1000           750        0.0000       0.00
# 438           NaN              1000           750        0.0000       0.00
# 439           NaN              1000           750        0.0000       0.00
# 424           NaN              1000           750        0.0000       0.00
# 423           NaN              1000           750        0.0000       0.00
# 422           NaN              1000           750        0.0000       0.00
# 421           NaN              1000           750        0.0000       0.00
# 406           NaN              1000           750        0.0000       0.00
# 407           NaN              1000           750        0.0000       0.00
# 408           NaN              1000           750        0.0000       0.00
# 409           NaN              1000           750        0.0000       0.00
# 410           NaN              1000           750        0.0000       0.00
# 411           NaN              1000           750        0.0000       0.00
# 412           NaN              1000           750        0.0000       0.00
# 413           NaN              1000           750        0.0000       0.00
# 414           NaN              1000           750        0.0000       0.00
# 415           NaN              1000           750        0.0000       0.00
# 416           NaN              1000           750        0.0000       0.00
# 417           NaN              1000           750        0.0000       0.00
# 418           NaN              1000           750        0.0000       0.00
# 419           NaN              1000           750        0.0000       0.00
# 420           NaN              1000           750        0.0000       0.00
# 1             NaN              1000           750        0.0000       0.00
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 749         62  ...          R     H      U                    2.0
# 750         44  ...          R     H      U                    2.0
# 751         48  ...          R     H      U                    2.0
# 752         52  ...          R     H      U                    2.0
# 753         56  ...          R     H      U                    2.0
# 774         48  ...          M     H      U                    1.0
# 771         38  ...          M     H      U                    1.0
# 772         42  ...          M     H      U                    1.0
# 773         44  ...          M     H      U                    1.0
# 775         38  ...          M     H      U                    1.0
# 777         44  ...          M     H      U                    1.0
# 776         42  ...          M     H      U                    1.0
# 778         48  ...          M     H      U                    1.0
# 792         58  ...          R     H      U                    2.0
# 793         44  ...          R     H      U                    2.0
# 794         48  ...          R     H      U                    2.0
# 796         58  ...          R     H      U                    2.0
# 795         52  ...          R     H      U                    2.0
# 790         48  ...          R     H      U                    2.0
# 789         44  ...          R     H      U                    2.0
# 791         52  ...          R     H      U                    2.0
# 966         46  ...          T     H      U                    3.0
# 969         60  ...          T     H      U                    3.0
# 954         46  ...          T     H      U                    3.0
# 955         50  ...          T     H      U                    3.0
# 956         54  ...          T     H      U                    3.0
# 968         54  ...          T     H      U                    3.0
# 957         60  ...          T     H      U                    3.0
# 967         50  ...          T     H      U                    3.0
# 781         46  ...          M     H      U                    1.0
# ...        ...  ...         ...   ...    ...                   ...
# 430        NaN  ...         NaN   NaN    NaN                   NaN
# 432        NaN  ...         NaN   NaN    NaN                   NaN
# 405        NaN  ...         NaN   NaN    NaN                   NaN
# 433        NaN  ...         NaN   NaN    NaN                   NaN
# 434        NaN  ...         NaN   NaN    NaN                   NaN
# 435        NaN  ...         NaN   NaN    NaN                   NaN
# 436        NaN  ...         NaN   NaN    NaN                   NaN
# 437        NaN  ...         NaN   NaN    NaN                   NaN
# 438        NaN  ...         NaN   NaN    NaN                   NaN
# 439        NaN  ...         NaN   NaN    NaN                   NaN
# 424        NaN  ...         NaN   NaN    NaN                   NaN
# 423        NaN  ...         NaN   NaN    NaN                   NaN
# 422        NaN  ...         NaN   NaN    NaN                   NaN
# 421        NaN  ...         NaN   NaN    NaN                   NaN
# 406        NaN  ...         NaN   NaN    NaN                   NaN
# 407        NaN  ...         NaN   NaN    NaN                   NaN
# 408        NaN  ...         NaN   NaN    NaN                   NaN
# 409        NaN  ...         NaN   NaN    NaN                   NaN
# 410        NaN  ...         NaN   NaN    NaN                   NaN
# 411        NaN  ...         NaN   NaN    NaN                   NaN
# 412        NaN  ...         NaN   NaN    NaN                   NaN
# 413        NaN  ...         NaN   NaN    NaN                   NaN
# 414        NaN  ...         NaN   NaN    NaN                   NaN
# 415        NaN  ...         NaN   NaN    NaN                   NaN
# 416        NaN  ...         NaN   NaN    NaN                   NaN
# 417        NaN  ...         NaN   NaN    NaN                   NaN
# 418        NaN  ...         NaN   NaN    NaN                   NaN
# 419        NaN  ...         NaN   NaN    NaN                   NaN
# 420        NaN  ...         NaN   NaN    NaN                   NaN
# 1          NaN  ...         NaN   NaN    NaN                   NaN
#
#           ProductModelID        SellStartDate          SellEndDate  \
# ProductID
# 749                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 750                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 751                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 752                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 753                 25.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 774                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 771                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 772                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 773                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 775                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 777                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 776                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 778                 19.0  2011-05-31 00:00:00  2012-05-29 00:00:00
# 792                 26.0  2012-05-30 00:00:00                  NaN
# 793                 26.0  2012-05-30 00:00:00                  NaN
# 794                 26.0  2012-05-30 00:00:00                  NaN
# 409        2014-02-08 10:01:36.827000000
# 410        2014-02-08 10:01:36.827000000
# 411        2014-02-08 10:01:36.827000000
# 412        2014-02-08 10:01:36.827000000
# 413        2014-02-08 10:01:36.827000000
# 414        2014-02-08 10:01:36.827000000
# 415        2014-02-08 10:01:36.827000000
# 416        2014-02-08 10:01:36.827000000
# 417        2014-02-08 10:01:36.827000000
# 418        2014-02-08 10:01:36.827000000
# 419        2014-02-08 10:01:36.827000000
# 420        2014-02-08 10:01:36.827000000
# 1          2014-02-08 10:01:36.827000000
#
# [504 rows x 24 columns]

# %% [markdown]
# This one is a little more advanced, but it demonstrates a few things:
# - Conversion of a `numpy.ndarray` object (return type of `pd.Series.unique()`) into a `pd.Series` object
# - `pd.Series.sort_values` with the `by=` kwarg omitted (if only one column is the operand, `by=` doesn't need specified
# - Alphabetical sort of a string field, `ascending=True` means A->Z
# - Inclusion of nulls, `NaN` in a string field (versus omission with a float/int as prior example)

# %% [markdown]
# ## Independent Exercises
#
# Do your best to complete the following prompts. Don't hesitate to look at code we wrote together!

# %% [markdown]
# Print the first 4 rows of the whole DataFrame.

# %%
# your answer here
prod.head(4)
# Out:
#                             Name   Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0   NaN
# 2                   Bearing Ball  BA-8327         0                  0   NaN
# 3                BB Ball Bearing  BE-2349         1                  0   NaN
# 4          Headset Ball Bearings  BE-2908         0                  0   NaN
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 1                      1000           750           0.0        0.0  NaN  ...
# 2                      1000           750           0.0        0.0  NaN  ...
# 3                       800           600           0.0        0.0  NaN  ...
# 4                       800           600           0.0        0.0  NaN  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 1                 NaN   NaN    NaN                   NaN            NaN
# 2                 NaN   NaN    NaN                   NaN            NaN
# 3                 NaN   NaN    NaN                   NaN            NaN
# 4                 NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
#
# [4 rows x 24 columns]

# %% [markdown]
# How many rows are in the dataframe? Return the answer as an int.

# %%
# your answer here
prod.shape[0]
# Out:
# 504

# %% [markdown]
# How many columns? Retrun the answer as an int.

# %%
# your answer here
prod.shape[1]
# Out:
# 24

# %% [markdown]
# How many different product lines are there?

# %%
# your answer here
prod["ProductLine"].nunique()
# Out:
# 4

# %% [markdown]
# What are the values of these product lines?

# %%
# your answer here
prod["ProductLine"].unique()
# Out:
# array([nan, 'R ', 'S ', 'M ', 'T '], dtype=object)

# %% [markdown]
# Do the number of values for the product lines match the number you have using `.nunique()`? Why or why not?

# %%
# your answer here
# no since nan is in the array

# %% [markdown]
# Take the output from your previous answer (using `.unique()`). Select the label corresponding to the `Road` product line using list indexing notation. How many characters are in this string?

# %%
# your answer here
prod["ProductLine"].unique()[1]
len(prod["ProductLine"].unique()[1])
# Out:
# 2

# %% [markdown]
# Do you notice anything odd about this?

# %%
# your answer here
# there's a space after it

# %% [markdown]
# How many products are there for the `Road` product line? Don't forget what you just worked on above! Return your answer as an int.

# %%
# your answer here
prod[prod["ProductLine"] == "R "].shape
# Out:
# (100, 24)

# %% [markdown]
# How many products are there in the `Women's` `Mountain` category? Return your answer as an int. _Hint: Use the data dictionary above!_

# %%
# your answer here
mountain_mask = prod["ProductLine"] == "M "
women_mask = prod["Style"] == "W "
prod[mountain_mask & women_mask]
prod[mountain_mask & women_mask].shape
# Out:
# (11, 24)

# %% [markdown]
# **Challenge:** What are the top 3 _most expensive list price_ product that are either in the `Women's` `Mountain` category, _OR_ `Silver` in `Color`? Return your answer as a DataFrame object, with the `ProductID` index, `NewName` relabeled as `Name`, and `ListPrice` columns. Perform the statement in one execution, and do not mutate the source DataFrame.

# %%
# your answer here
silver_mask = prod["Color"] == "Silver"
prod[silver_mask].shape
# Out:
# (43, 24)

# %%
prod[(mountain_mask & women_mask) | silver_mask].sort_values(by="ListPrice", ascending=False).head(3)[["Name", "ListPrice"]]
# Out:
#                               Name  ListPrice
# ProductID
# 774        Mountain-100 Silver, 48    3399.99
# 771        Mountain-100 Silver, 38    3399.99
# 772        Mountain-100 Silver, 42    3399.99

# %%
prod[(mountain_mask & women_mask) | silver_mask].sort_values(by="ListPrice", ascending=False).tail(3)[["Name", "ListPrice"]]
# Out:
#                             Name  ListPrice
# ProductID
# 351        Front Derailleur Cage        0.0
# 332                    Freewheel        0.0
# 320              Chainring Bolts        0.0

# %% [markdown]
# ## Recap
#
# We covered a lot of ground! It's ok if this takes a while to gel.
#
# ```python
#
# # basic DataFrame operations
# df.head()
# df.tail()
# df.shape
# df.columns
# df.Index
#
# # selecting columns
# df.column_name
# df['column_name']
#
# # renaming columns
# df.rename({'old_name':'new_name'}, inplace=True)
# df.columns = ['new_column_a', 'new_column_b']
#
# # notable columns operations
# df.describe() # five number summary
# df['col1'].nunique() # number of unique values
# df['col1'].value_counts() # number of occurrences of each value in column
#
# # filtering
# df[ df['col1'] < 50 ] # filter column to be less than 50
# df[ (df['col1'] == value1) & (df['col2'] > value2) ] # filter column where col1 is equal to value1 AND col2 is greater to value 2
#
# # sorting
# df.sort_values(by='column_name', ascending = False) # sort biggest to smallest
#
# ```
#
#
# It's common to refer back to your own code *all the time.* Don't hesistate to reference this guide! 🐼
